# %% [markdown]
# # 循环神经网络 RNN

# %% [markdown]
# 隐hide变量：存在但未被观测到
#
# 潜late变量：可以不存在

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 输出发生在观察之前

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 老师ppt里输入是错位的，paper里：
#
# ![image-3.png](attachment:image-3.png)
#
# 1. 隐变量取决于“上一层隐变量”和“当前输入”
#
# 2. 当前输出取决于“当前隐变量”（进而间接取决于上一层隐变量和当前输入）。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 困惑度放大误差，1为完美

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# g 是所有层梯度，g的长度就是L2范数（所有梯度值平方和的平方根），超过theta就赋值theta，不超过就全部保留

# %% [markdown]
# 梯度裁剪控制上限，残差连接控制下限，都是保证梯度有效传播

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
