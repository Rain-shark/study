# %% [markdown]
# 动手学深度学习 v2 - 从零开始介绍深度学习算法和代码实现
#
# 课程主页：https://courses.d2l.ai/zh-v2/
#
# 教材：https://zh-v2.d2l.ai/
#
# 代码：https://github.com/d2l-ai/d2l-zh/tree/master

# %% [markdown]
# 文件夹中0-13文件夹按课程教材命名
#
# .ipynb文件按B站视频命名

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
