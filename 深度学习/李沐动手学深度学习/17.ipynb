# %% [markdown]
# 购买使用GPU

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 如果不想买卡的话平时学习可以用Kaggle（首推）、colab（需要梯子）、阿里云天池、paddleaudio（仅限paddle框架）这些平台去使用免费的算力资源，可以用到Nvidia T4、P100、Tesla A100不等。 自己买卡的话推荐显存12G以上的，有能力上16G，买更大的显存意味着以后能学习、部署一些主流的技术模型，接触到最前沿。
