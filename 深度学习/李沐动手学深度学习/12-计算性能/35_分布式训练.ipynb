# %% [markdown]
# # 分布式训练

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# 同步随机梯度下降（SGD）

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# t1（计算任务）和 t2（通信任务）在时间上是并行执行的，t1越大，越忽略t2，系统性能越好。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q：分布式集群下训练时，为什么计算和数据通讯可以并行?单机上不是要等梯度算完，传到参数服务器上，等等所有梯度集合更新后，才能拿到下一个新的模型参数吗
#
# A：前向传播时是一个算完才能算下一个，反向传播使用前向传播数据，backward 比 forward 滞后一个 batch，不用等上一个梯度。即 forward 不能并行，但 backward 可以并行。
