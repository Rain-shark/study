# %% [markdown]
# # 深度学习硬件：CPU 和 GPU

# %% [markdown]
# cpu：中央处理器，核心少，通用计算，需要处理整个计算机的允许
#
# gpu：图形处理器，核心极多，专注于高性能、并行计算，适合处理深度学习的矩阵运算等

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
